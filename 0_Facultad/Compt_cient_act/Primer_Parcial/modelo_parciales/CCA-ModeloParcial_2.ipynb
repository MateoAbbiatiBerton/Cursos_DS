# %% [markdown]
# <h1 style="text-align: center;">Universidad de Buenos Aires - Facultad de Ciencias Económicas</h1>

# %% [markdown]
# <h2 style="text-align: center;">Computación Científica Actuarial - Recuperatorio Segundo Parcial - 2C2023</h2>

# %% [markdown]
# **Docente**: Rodrigo del Rosso
#
# **Fecha**: sábado 2 de diciembre 2023
#
# ***

# %% [markdown]
# #### Consideraciones
# El presente examen constituye el recuperatorio de la segunda instancia de evaluación de la materia Computación Científica
# Actuarial, materia optativa de la Carrera de Actuario de la Universidad de Buenos Aires (modalidad
# virtual).
#
# La finalidad es articular los conceptos teóricos estudiados en las clases mediante la utilización de Python.
#
# Algunas cuestiones prácticas:
# 1. Tienen hasta las 13:00 de ese día para entregar el examen mediante el campus virtual en el espacio
# reservado.
# 2. El examen es individual.
# 4. Deberán subir como máximo 1 archivo: un archivo del script (.ipynb) con la resolución de los ejercicios.
# 5. El **nombre del archivo** y de la **entrega en el campus** deberán ser ***R2P_número_registro.ipynb*** y ***2P_número_registro***, respectivamente. Por ejemplo, *R2P_987123.ipynb* y *R2P_987123*.
#
# Los siguientes ejercicios deberán resolverlos mediante la utilización de Python. El puntaje mínimo para aprobar
# es de 60 puntos. Cada ejercicio cuenta con el puntaje que otorga su resolución en
# forma completa y correcta.
#
# ***
# <h2 style="color:rgb(255,0,0);">IMPORTANTE</h2>
#
# * **NO modificar los nombres de las funciones**.
# * **Únicamente se deberá escribir código de Python dentro de los espacios designados por:**
#
# ```python
#
#     ##############################
#     # Tu respuesta comienza aquí #
#     ##############################
#
#     >> mi código va acá
#
#     ##############################
#     # Tu respuesta termina aquí  #
#     ##############################
# ```
#
# * <body><p> Para que el ejercicio sea computado como <span style="color:rgb(0,255,0);">CORRECTO</span> <b>debe pasar todos <i>tests</i> (pruebas) que se encuentran al final del archivo.</b></p></body>
# ***
# #### Puntajes por ejercicio
#
# <table>
#   <tr>
#     <th>Ejercicio</th>
#     <th>Valor</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>20</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>20</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>20</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>20</td>
#   </tr>
#   <tr>
#     <td>5</td>
#     <td>20</td>
#   </tr>
#   <tr>
#     <th>Total</th>
#     <th><strong>100</strong></th>
#   </tr>
# </table>

# %%
### Estos son los únicos imports que se requieren en esta evaluación ###
import pandas as pd
import numpy as np

# %% [markdown]
# ***
# ### Ejercicio 1
#
# Armar una función tal que, dada una `tuple`, devuelva los $n-k$ mayores valores ordenados en forma descente, donde $n$ es la cantidad de elementos en la `tuple` y $k$ es un número entero ($k < n$).

# %%
def func1(tup, k):
    """
    Devuelve una tupla con los elementos ordenados de forma descendente
    y excluye los últimos 'k' elementos.

    Parameters:
    - tup (tuple): Tupla de elementos.
    - k (int): Número de elementos a excluir desde el final.

    Returns:
    tuple: Tupla resultante después de ordenar de forma descendente y excluir 'k' elementos.
    """
    ##############################
    # Tu respuesta comienza aquí #
    ##############################
    
    
    
    
    ##############################
    # Tu respuesta termina aquí  #
    ##############################
    
    return respuesta

# %% [markdown]
# ***
# ### Ejercicio 2
#
# Crear una función tal que, dado listado de `list` o `tuple`, genere una matriz de $N x M$, donde N es la cantidad de columnas, dado por el largo máximo de las `list` o `tuple`; y M la cantidad de filas. En caso de tener diferentes largos, usar el máximo largo disponible y completar los demás espacios con valor 0. En caso de ser un listado vacío, devolver un `np.ndarray` vacío.

# %%
def func2(l):
    """
    Crea una matriz NumPy a partir de una lista de listas, llenando con ceros 
    las posiciones restantes para que todas las sublistas tengan la misma longitud.

    Parameters:
    - l (list): Lista de listas o tuplas.

    Returns:
    numpy.ndarray: Matriz resultante con las sublistas rellenadas de ceros.
    """
    ##############################
    # Tu respuesta comienza aquí #
    ##############################
    
    
    
    
    ##############################
    # Tu respuesta termina aquí  #
    ##############################
        
    return respuesta

# %% [markdown]
# ***
# ### Ejercicio 3
#
# Crear una función tal que dado un `pd.DataFrame`, cuyas columnas solo poseen valores numéricos (puede tener nulos que deberán ser eliminados del objeto, descartando toda la fila):
# 1. Devuelva una lista con los nombres de las columnas, ordenados según el máximo valor que se encuentra en dicha columna.
# 2. Sume cada columna de forma vectorial, respetando el orden del punto 1, teniendo en cuenta que nueva columna que adicionada deberá ser múltiplicada por el valor $i$, donde $i$ representa el núnmero de columnas adicionadas (el primer valor es 1).
# 3. Devuelva el máximo, mínimo y promedio de la columna obtenida en el punto 2.

# %%
import pandas as pd
import numpy as np

def func3(df):
    """
    Realiza operaciones sobre un DataFrame de Pandas.

    Elimina filas con valores nulos, ordena las columnas según el máximo valor,
    y calcula la suma ponderada de las columnas.

    Parameters:
    - df (pd.DataFrame): DataFrame de Pandas.

    Returns:
    tuple: Una tupla con los siguientes elementos:
        - columnas_ordenadas (list): Nombres de columnas ordenados según el máximo valor.
        - suma_columnas (numpy.ndarray): Suma ponderada de las columnas.
        - maximo (float): Máximo valor de la columna resultante.
        - minimo (float): Mínimo valor de la columna resultante.
        - promedio (float): Promedio de la columna resultante.
    """
    ##############################
    # Tu respuesta comienza aquí #
    ##############################
    
    
    
    
    ##############################
    # Tu respuesta termina aquí  #
    ##############################
    
    return columnas_ordenadas, suma_columnas, maximo, minimo, promedio

# %% [markdown]
# ***
# ### Ejercicio 4
#
# Dado un `string` (en este caso, una frase) se pide:
# 1. contar la cantidad de palabras únicas
# 1. eliminar todas las palabras duplicadas; conservando la primer aparación de la misma
# 1. encontrar la palabra con mayor cantidad de letras
# 1. encontrar la palabra con la mayor cantidad de letras repetidas

# %%
def func4(frase):
    """
    Realiza operaciones sobre una frase.

    Divide la frase en palabras, cuenta la cantidad de palabras únicas,
    elimina palabras duplicadas conservando la primera aparición,
    encuentra la palabra con la mayor cantidad de letras y la palabra
    con la mayor cantidad de letras repetidas.

    Parameters:
    - frase (str): Frase de entrada.

    Returns:
    tuple: Una tupla con los siguientes elementos:
        - cantidad_palabras_unicas (int): Cantidad de palabras únicas.
        - palabras_sin_duplicados (list): Lista de palabras sin duplicados.
        - palabra_max_longitud (str): Palabra con la mayor cantidad de letras.
        - palabra_max_repetidas (str): Palabra con la mayor cantidad de letras repetidas.

    """
    
    ##############################
    # Tu respuesta comienza aquí #
    ##############################
    
    
    
    
    ##############################
    # Tu respuesta termina aquí  #
    ##############################
    
    return cantidad_palabras_unicas, palabras_sin_duplicados, palabra_max_longitud, palabra_max_repetidas

# %% [markdown]
# ***
# ### Ejercicio 5
#
# Dado un `dict` con los puntajes obtenidos en cada ejercicio por el estudiante, determinar la calificación final del correspondiente examen.
#
# Las posibles calificaciones son:
# * A: si el puntaje obtenido es mayor o igual a 90
# * B: si el puntaje obtenidos es mayor o igual a 75 y menor a 90
# * C: si el puntaje obtenidos es mayor o igual a 60 y menor a 75
# * D: si es menor a 60
#
# Otras cuestiones:
# * Cada ejercicio vale un máximo de 25 puntos. Si no se cumple, devolver X.
# * Deben ser sí o sí 4 ejercicios. Si no se cumple, devolver X.
# * El output debe ser un `str`.
#
# El input viene dado de la siguiente forma:
#
# ```python
# puntajes_estudiante = {'ejercicio1': int, 'ejercicio2': int, 'ejercicio3': int, 'ejercicio4': int}
# ```

# %%
def func5(puntajes):
    
    """
    Determina la calificación final del estudiante según los puntajes obtenidos en 4 ejercicios.

    Parameters:
    - puntajes (dict): Un diccionario con los puntajes obtenidos en cada ejercicio.

    Returns:
    str: La calificación final según las siguientes reglas:
        - 'A': Puntaje total mayor o igual a 90.
        - 'B': Puntaje total mayor o igual a 75 y menor a 90.
        - 'C': Puntaje total mayor o igual a 60 y menor a 75.
        - 'D': Puntaje total menor a 60.
        - 'X': En caso de no cumplir con la cantidad de ejercicios (deben ser 4) o si algún ejercicio supera los 25 puntos.

    """
    
    ##############################
    # Tu respuesta comienza aquí #
    ##############################
    
    ##### SE DEBE REEMPLAZAR LOS '...' POR CÓDIGO #####
    
    # Chequear que sean 4 ejercicios
    if ...:
        return 'X'
    
    # Chequear si todos los ejercicios cumplen la restricción de max 25 puntos
    if ...:
        return 'X'
    
    # Calcular el puntaje total obtenido
    puntaje_obtenido = ...
    
    # Determinar la calificación según el puntaje
    if ...:
        return 'A'
    elif ...:
        return 'B'
    elif ...:
        return 'C'
    else:
        return 'D'
    
    ##############################
    # Tu respuesta termina aquí  #
    ##############################

# %% [markdown]
# ***
# ***
# <h2 style="color:rgb(245, 230, 24);">ESPACIO RESERVADO PARA TESTS - NO MODIFICAR NINGUNA LINEA DE CODIGO</h2>
#
# ***
# ***

# %%
import unittest
import pandas as pd
import numpy as np

# %% [markdown]
# #### TESTS EJERCICIO 1

# %%
class TestFunc1(unittest.TestCase):
    
    def __init__(self):
        super().__init__()
        self.score = 0
        
        self.test1 = 0
        self.test2 = 0
        self.test3 = 0
        self.test4 = 0
        self.test_empty = 0
        
    def test_case_1(self):
        input_tuple = (5, 2, 8, 1, 3)
        k_value = 2
        result = func1(input_tuple, k_value)
        self.assertEqual(result, (8, 5, 3))
        print('Test 1: Ok')
        self.test1 = 1
        
    def test_case_2(self):
        input_tuple = (10, 5, 3, 7, 1)
        k_value = 1
        result = func1(input_tuple, k_value)
        self.assertEqual(result, (10, 7, 5, 3))
        print('Test 2: Ok')
        self.test2 = 1
        
    def test_case_3(self):
        input_tuple = (1, 2, 3, 4, 5)
        k_value = 0
        result = func1(input_tuple, k_value)
        self.assertEqual(result, (5, 4, 3, 2, 1))
        print('Test 3: Ok')
        self.test3 = 1
        
    def test_case_4(self):
        input_tuple = (1, 2, 3, 4, 5)
        k_value = 6
        result = func1(input_tuple, k_value)
        self.assertEqual(result, None)
        print('Test 4: Ok')
        self.test4 = 1
        
    def test_empty_tuple(self):
        input_tuple = ()
        k_value = 0
        result = func1(input_tuple, k_value)
        self.assertEqual(result, None)
        print('Test test_empty_tuple: Ok')
        self.test_empty = 1
        
    def score_value(self):
        
        if sum([self.test1, self.test2, self.test3, self.test4, self.test_empty]) == 5:
        
            self.score =  1

# %%
tf1 = TestFunc1()
tf1.test_case_1()
tf1.test_case_2()
tf1.test_case_3()
tf1.test_case_4()
tf1.test_empty_tuple()

# %%
tf1.score_value()

ejercicio_1 = tf1.score

# %% [markdown]
# #### TESTS EJERCICIO 2

# %%
class TestFunc2(unittest.TestCase):
    
    def __init__(self):
        super().__init__()
        self.score = 0
        
        self.test1 = 0
        self.test2 = 0
        self.test3 = 0
        self.test4 = 0
        
    def test_case_1(self):
        input_listado = [(1, 2, 3), [4, 5, 6, 7], [8, 9]]
        result = func2(input_listado)
        expected_result = np.array([[1, 2, 3, 0], [4, 5, 6, 7], [8, 9, 0, 0]])
        np.testing.assert_array_equal(result, expected_result)
        print('Test 1: Ok')
        self.test1 = 1
        
    def test_case_2(self):
        input_listado = [(10, 5, 3, 7, 1), [2, 4, 6]]
        result = func2(input_listado)
        expected_result = np.array([[10, 5, 3, 7, 1], [2, 4, 6, 0, 0]])
        np.testing.assert_array_equal(result, expected_result)
        print('Test 2: Ok')
        self.test2 = 1
        
    def test_case_3(self):
        input_listado = [(1,), [2, 3, 4, 5], [6, 7, 8]]
        result = func2(input_listado)
        expected_result = np.array([[1, 0, 0, 0], [2, 3, 4, 5], [6, 7, 8, 0]])
        np.testing.assert_array_equal(result, expected_result)
        print('Test 3: Ok')
        self.test3 = 1
        
    def test_empty_tuple(self):
        input_listado = []
        result = func2(input_listado)
        expected_result = np.array([])
        np.testing.assert_array_equal(result, expected_result)
        print('Test 4: Ok')
        self.test4 = 1
        
    def score_value(self):
        
        if sum([self.test1, self.test2, self.test3, self.test4]) == 4:
        
            self.score =  1

# %%
tf2 = TestFunc2()
tf2.test_case_1()
tf2.test_case_2()
tf2.test_case_3()
tf2.test_empty_tuple()

# %%
tf2.score_value()
ejercicio_2 = tf2.score

# %% [markdown]
# #### TESTS EJERCICIO 3

# %%
class TestFunc3(unittest.TestCase):
    
    def __init__(self):
        super().__init__()
        self.score = 0
        
        self.test1 = 0
        self.test2 = 0
        self.test3 = 0
        
    def test_caso_general(self):
        data = {'A': [1, 2, np.nan, 4], 'B': [5, 6, 7, 8], 'C': [9, 10, 11, 12]}
        df = pd.DataFrame(data)
        resultados = func3(df)

        self.assertEqual(resultados[0], ['C', 'B', 'A'])
        np.testing.assert_array_equal(resultados[1], np.array([22, 28, 40]))
        self.assertEqual(resultados[2], 40)
        self.assertEqual(resultados[3], 22)
        self.assertEqual(resultados[4], 30)
        
        print('Test 1: Ok')
        self.test1 = 1
        
    def test_sin_nulos(self):
        data = {'A': [1, 2, 3, 4], 'B': [5, 6, 7, 8], 'C': [9, 10, 11, 12]}
        df = pd.DataFrame(data)
        resultados = func3(df)

        self.assertEqual(resultados[0], ['C', 'B', 'A'])
        np.testing.assert_array_equal(resultados[1], np.array([22, 28, 34, 40]))
        self.assertEqual(resultados[2], 40)
        self.assertEqual(resultados[3], 22)
        self.assertEqual(resultados[4], 31)
        
        print('Test 2: Ok')
        self.test2 = 1
        
    def test_orden_columnas_especifico(self):
        data = {'A': [1, 2, np.nan, 20], 'B': [5, 6, 7, 8], 'C': [9, 10, 11, 10]}
        df = pd.DataFrame(data)
        resultados = func3(df)
        # Se espera que el orden de las columnas sea 'A', 'C', 'B'
        self.assertEqual(resultados[0], ['A', 'C', 'B'])
        np.testing.assert_array_equal(resultados[1], np.array([34, 40, 64]))
        self.assertEqual(resultados[2], 64)
        self.assertEqual(resultados[3], 34)
        self.assertEqual(resultados[4], 46)
        
        print('Test 3: Ok')
        self.test3 = 1
        
    def score_value(self):
        
        if sum([self.test1, self.test2, self.test3]) == 3:
        
            self.score =  1

# %%
tf3 = TestFunc3()
tf3.test_caso_general()
tf3.test_sin_nulos()
tf3.test_orden_columnas_especifico()

# %%
tf3.score_value()
ejercicio_3 = tf3.score

# %% [markdown]
# #### TESTS EJERCICIO 4

# %%
class TestFunc4(unittest.TestCase):

    def __init__(self):
        super().__init__()
        self.score = 0
        
        self.test1 = 0
        self.test2 = 0
        self.test3 = 0
        
    def test_case_1(self):
        frase = "python es un lenguaje de programacion python es versatil python es potente"
        resultados = func4(frase)

        self.assertEqual(resultados[0], 8)
        self.assertEqual(resultados[1], ['python', 'es', 'un', 'lenguaje', 'de', 'programacion', 'versatil', 'potente'])
        self.assertEqual(resultados[2], 'programacion')
        self.assertEqual(resultados[3], 'programacion')

        print('Test 1: Ok')
        self.test1 = 1

    def test_case_2(self):
        frase = "casa casa casa azul azul campo"
        resultados = func4(frase)

        self.assertEqual(resultados[0], 3)
        self.assertEqual(resultados[1], ['casa', 'azul', 'campo'])
        self.assertEqual(resultados[2], 'campo')
        self.assertEqual(resultados[3], 'casa')

        print('Test 2: Ok')
        self.test2 = 1

    def test_case_3(self):
        frase = "Es uno de los métodos más comunes para generar números pseudoaleatorios"
        resultados = func4(frase)

        self.assertEqual(resultados[0], 11)
        self.assertEqual(resultados[1], ['Es', 'uno', 'de', 'los', 'métodos', 'más', 'comunes', 'para', 'generar', 'números', 'pseudoaleatorios'])
        self.assertEqual(resultados[2], 'pseudoaleatorios')
        self.assertEqual(resultados[3], 'pseudoaleatorios')

        print('Test 3: Ok')
        self.test3 = 1

    def score_value(self):
        if sum([self.test1, self.test2, self.test3]) == 3:
            self.score = 1

# %%
tf4 = TestFunc4()
tf4.test_case_1()
tf4.test_case_2()
tf4.test_case_3()

# %%
tf4.score_value()
ejercicio_4 = tf4.score

# %% [markdown]
# #### TEST EJERCICIO 5

# %%
class TestFunc5(unittest.TestCase):
    
    def __init__(self):
        super().__init__()
        self.score = 0
        
        self.test1 = 0
        self.test2 = 0
        self.test3 = 0
        self.test4 = 0
        self.test5 = 0
        
    def test_calificacion_a(self):
        puntajes = {'ejercicio1': 25, 'ejercicio2': 25, 'ejercicio3': 25, 'ejercicio4': 25}
        resultado = func5(puntajes)
        self.assertEqual(resultado, 'A')
        
        print('Test 1: Ok')
        self.test1 = 1
        
    def test_calificacion_b(self):
        puntajes = {'ejercicio1': 20, 'ejercicio2': 25, 'ejercicio3': 18, 'ejercicio4': 15}
        resultado = func5(puntajes)
        self.assertEqual(resultado, 'B')
        
        print('Test 2: Ok')
        self.test2 = 1
        
    def test_calificacion_c(self):
        puntajes = {'ejercicio1': 15, 'ejercicio2': 15, 'ejercicio3': 15, 'ejercicio4': 15}
        resultado = func5(puntajes)
        self.assertEqual(resultado, 'C')
        
        print('Test 3: Ok')
        self.test3 = 1
        
    def test_calificacion_d(self):
        puntajes = {'ejercicio1': 5, 'ejercicio2': 10, 'ejercicio3': 10, 'ejercicio4': 5}
        resultado = func5(puntajes)
        self.assertEqual(resultado, 'D')
        
        print('Test 4: Ok')
        self.test4 = 1
        
    def test_calificacion_x_puntaje_maximo(self):
        puntajes = {'ejercicio1': 35, 'ejercicio2': 25, 'ejercicio3': 15, 'ejercicio4': 18}
        resultado = func5(puntajes)
        self.assertEqual(resultado, 'X')
        
        print('Test 5: Ok')
        self.test5 = 1
        
    def test_cant_ejercicios(self):
        puntajes = {'ejercicio1': 20, 'ejercicio2': 20, 'ejercicio3': 20}
        resultado = func5(puntajes)
        self.assertEqual(resultado, 'X')
        
        print('Test 6: Ok')
        self.test6 = 1
        
    def score_value(self):
        if sum([self.test1, self.test2, self.test3, self.test4, self.test5, self.test6]) == 6:
            self.score = 1

# %%
tf5 = TestFunc5()
tf5.test_calificacion_a()
tf5.test_calificacion_b()
tf5.test_calificacion_c()
tf5.test_calificacion_d()
tf5.test_calificacion_x_puntaje_maximo()
tf5.test_cant_ejercicios()

# %%
tf5.score_value()
ejercicio_5 = tf5.score

# %% [markdown]
# ***
# ### RESULTADO FINAL

# %%
RES = pd.DataFrame([ejercicio_1, ejercicio_2, ejercicio_3, ejercicio_4, ejercicio_5], index= [1,2,3,4,5], columns=['Resuelto OK']).rename_axis('EJERCICIO').reset_index()

# %%
if RES['Resuelto OK'].sum() < 3:
    print('Reprobado: 2')
    
elif RES['Resuelto OK'].sum() == 3:
    print('Aprobado: 4')
    
elif RES['Resuelto OK'].sum() == 4:
    print('Aprobado: 7')

elif RES['Resuelto OK'].sum() == 5:
    print('Aprobado: 10')
    
else:
    print('Algo salió mal...')
